# %%
# !pip install pandas numpy matplotlib seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\usuario\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\users\usuario\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip
# Out:
# Usage:
#   pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --debug                     Let unhandled exceptions propagate outside the
#                               main subroutine, instead of logging them to
#                               stderr.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   --require-virtualenv        Allow pip to only run in a virtual environment;
#                               exit with an error otherwise.
#   --python <python>           Run pip with the specified Python interpreter.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#   --no-input                  Disable prompting for input.
#   --keyring-provider <keyring_provider>
#                               Enable the credential lookup via the keyring
#                               library if user input is allowed. Specify which
#                               mechanism to use [disabled, import, subprocess].
#                               (default: disabled)
#   --proxy <proxy>             Specify a proxy in the form
#                               scheme://[user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum number of retries each connection should
#                               attempt (default 5 times).
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to PEM-encoded CA certificate bundle. If
#                               provided, overrides the default. See 'SSL
#                               Certificate Verification' in pip documentation
#                               for more information.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output.
#   --no-python-version-warning
#                               Silence deprecation warnings for upcoming
#                               unsupported Pythons.
#   --use-feature <feature>     Enable new functionality, that may be backward
#                               incompatible.
#   --use-deprecated <feature>  Enable deprecated functionality, that will be
#                               removed in the future.

# %%
import numpy as np

# %%
df_bosque = pd.read_csv('estado_conservacion.csv')

print(df_bosque)
# Out:
#     Código_Piso                                        Nombre_Piso  \
# 0            P1   Desierto tropical interior con vegetación escasa
# 1            P2  Dunas tropicales costeras de Tillandsia landbe...
# 2            P3  Herbazal efímero tropical costero de Nolana ad...
# 3            P4  Matorral desértico tropical interior Malesherb...
# 4            P5  Matorral desértico tropical interior de Atripl...
# ..          ...                                                ...
# 120        P121  Herbazal antiboreal andino de Nassauvia pygmae...
# 121        P122  Estepa mediterránea-templada oriental de Festu...
# 122        P123  Estepa mediterránea oriental de Festuca gracil...
# 123        P124  Estepa mediterránea-templada oriental de Festu...
# 124        P125  Estepa mediterránea-templada oriental de Festu...
#
#                 Formación  Superficie_total_(km2)  \
# 0                Desierto                   58005
# 1      Dunas de aerófitos                     381
# 2        Herbazal efímero                     757
# 3      Matorral desértico                     533
# 4      Matorral desértico                    8803
# ..                    ...                     ...
# 120   Herbazal de altitud                    4401
# 121  Estepas y Pastizales                    3271
# 122  Estepas y Pastizales                    6354
# 123  Estepas y Pastizales                    6892
# 124  Estepas y Pastizales                    8029
#
#      Superficie_remanente _(km2)  Pérdida_proyectada_50_años_(%)  \
# 0                          56722                        0.000189
# 1                            381                        0.000000
# 2                            732                        0.152546
# 3                            529                        0.000000
# 4                           8484                       -0.011059
# ..                           ...                             ...
# 120                         4401                        0.000000
# 121                         3127                        0.000000
# 122                         6354                        0.000000
# 123                         6890                        0.000000
# 124                         7983                        0.000000
#
#      Pérdida_Histórica_(%) Criterio_UICN_A2b Criterio_UICN_A3 Evaluación_Final
# 0                 2.212528                LC               LC               LC
# 1                 0.005251                LC               LC               LC
# 2                 3.328353                LC               LC               LC
# 3                 0.774401                LC               LC               LC
# 4                 3.616477                LC               LC               LC
# ..                     ...               ...              ...              ...
# 120               0.000000                LC               LC               LC
# 121               4.382314                LC               LC               LC
# 122               0.000000                LC               LC               LC
# 123               0.034168                LC               LC               LC
# 124               0.565801                LC               LC               LC
#
# [125 rows x 10 columns]

# %%
df_bosque.head(125)
# Out:
#     Código_Piso                                        Nombre_Piso  \
# 0            P1   Desierto tropical interior con vegetación escasa
# 1            P2  Dunas tropicales costeras de Tillandsia landbe...
# 2            P3  Herbazal efímero tropical costero de Nolana ad...
# 3            P4  Matorral desértico tropical interior Malesherb...
# 4            P5  Matorral desértico tropical interior de Atripl...
# ..          ...                                                ...
# 120        P121  Herbazal antiboreal andino de Nassauvia pygmae...
# 121        P122  Estepa mediterránea-templada oriental de Festu...
# 122        P123  Estepa mediterránea oriental de Festuca gracil...
# 123        P124  Estepa mediterránea-templada oriental de Festu...
# 124        P125  Estepa mediterránea-templada oriental de Festu...
#
#                 Formación  Superficie_total_(km2)  \
# 0                Desierto                   58005
# 1      Dunas de aerófitos                     381
# 2        Herbazal efímero                     757
# 3      Matorral desértico                     533
# 4      Matorral desértico                    8803
# ..                    ...                     ...
# 120   Herbazal de altitud                    4401
# 121  Estepas y Pastizales                    3271
# 122  Estepas y Pastizales                    6354
# 123  Estepas y Pastizales                    6892
# 124  Estepas y Pastizales                    8029
#
#      Superficie_remanente _(km2)  Pérdida_proyectada_50_años_(%)  \
# 0                          56722                        0.000189
# 1                            381                        0.000000
# 2                            732                        0.152546
# 3                            529                        0.000000
# 4                           8484                       -0.011059
# ..                           ...                             ...
# 120                         4401                        0.000000
# 121                         3127                        0.000000
# 122                         6354                        0.000000
# 123                         6890                        0.000000
# 124                         7983                        0.000000
#
#      Pérdida_Histórica_(%) Criterio_UICN_A2b Criterio_UICN_A3 Evaluación_Final
# 0                 2.212528                LC               LC               LC
# 1                 0.005251                LC               LC               LC
# 2                 3.328353                LC               LC               LC
# 3                 0.774401                LC               LC               LC
# 4                 3.616477                LC               LC               LC
# ..                     ...               ...              ...              ...
# 120               0.000000                LC               LC               LC
# 121               4.382314                LC               LC               LC
# 122               0.000000                LC               LC               LC
# 123               0.034168                LC               LC               LC
# 124               0.565801                LC               LC               LC
#
# [125 rows x 10 columns]

# %%
print(df_bosque.shape)
# Out:
# (125, 10)

# %%
df_bosque.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código_Piso                     125 non-null    object
#  1   Nombre_Piso                     125 non-null    object
#  2   Formación                       125 non-null    object
#  3   Superficie_total_(km2)          125 non-null    int64
#  4   Superficie_remanente _(km2)     125 non-null    int64
#  5   Pérdida_proyectada_50_años_(%)  125 non-null    float64
#  6   Pérdida_Histórica_(%)           125 non-null    float64
#  7   Criterio_UICN_A2b               125 non-null    object
#  8   Criterio_UICN_A3                125 non-null    object
#  9   Evaluación_Final                125 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 9.9+ KB

# %%
df_bosque = df_bosque.dropna(subset=["Formación"])
print(df_bosque.shape)
df_bosque["Formación"].sum
# Out:
# (125, 10)
# <bound method Series.sum of 0                  Desierto
# 1        Dunas de aerófitos
# 2          Herbazal efímero
# 3        Matorral desértico
# 4        Matorral desértico
#                ...
# 120     Herbazal de altitud
# 121    Estepas y Pastizales
# 122    Estepas y Pastizales
# 123    Estepas y Pastizales
# 124    Estepas y Pastizales
# Name: Formación, Length: 125, dtype: object>

# %%
df_bosque.head(125)

# %%
df_bosque.groupby(["Formación"]).agg(mean_perdida=("Pérdida_proyectada_50_años_(%)", "mean"),
                                 total=("Superficie_total_(km2)", "count"))
# Out:
#                               mean_perdida  total
# Formación
# Bosque caducifolio               42.783671     21
# Bosque esclerofilo               43.457923      8
# Bosque espinoso                  16.873649      7
# Bosque laurifolio                43.610702      3
# Bosque resinoso de coníferas      1.401380      7
# Bosque siempreverde               0.092779     11
# Desierto                          0.000189      1
# Dunas de aerófitos                0.000000      1
# Estepas y Pastizales              0.000000      4
# Herbazal de altitud               0.000000      4
# Herbazal de altitudl              0.000000      1
# Herbazal efímero                  0.152546      1
# Matorral bajo de altitud          0.026815     20
# Matorral bajo desértico          -0.002445      5
# Matorral caducifolio              0.000000      4
# Matorral desértico                0.025853     18
# Matorral esclerofilo              3.516928      2
# Matorral espinoso                 0.098076      2
# Matorral siempreverde             0.000000      1
# Turbera                           0.000000      4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
sns.reset_defaults
# Out:
# <function seaborn.rcmod.reset_defaults()>

# %%
print(df_bosque.groupby("Formación")["Pérdida_proyectada_50_años_(%)"].describe())   # analisis descripivo de las formaciones.
# Out:
#                               count       mean        std       min  \
# Formación
# Bosque caducifolio             21.0  42.783671  46.788293  0.000000
# Bosque esclerofilo              8.0  43.457923  46.178295  0.000000
# Bosque espinoso                 7.0  16.873649  27.447318 -0.000834
# Bosque laurifolio               3.0  43.610702  49.938188  4.975366
# Bosque resinoso de coníferas    7.0   1.401380   2.336441  0.000000
# Bosque siempreverde            11.0   0.092779   0.290598  0.000000
# Desierto                        1.0   0.000189        NaN  0.000189
# Dunas de aerófitos              1.0   0.000000        NaN  0.000000
# Estepas y Pastizales            4.0   0.000000   0.000000  0.000000
# Herbazal de altitud             4.0   0.000000   0.000000  0.000000
# Herbazal de altitudl            1.0   0.000000        NaN  0.000000
# Herbazal efímero                1.0   0.152546        NaN  0.152546
# Matorral bajo de altitud       20.0   0.026815   0.084822 -0.008080
# Matorral bajo desértico         5.0  -0.002445   0.002854 -0.007248
# Matorral caducifolio            4.0   0.000000   0.000000  0.000000
# Matorral desértico             18.0   0.025853   0.049059 -0.011059
# Matorral esclerofilo            2.0   3.516928   4.970675  0.002130
# Matorral espinoso               2.0   0.098076   0.099528  0.027699
# Matorral siempreverde           1.0   0.000000        NaN  0.000000
# Turbera                         4.0   0.000000   0.000000  0.000000
#
#                                     25%        50%         75%         max
# Formación
# Bosque caducifolio             0.312712   2.433394  100.000000  100.000000
# Bosque esclerofilo             3.688422  25.834129   92.842492  100.000000
# Bosque espinoso                0.171677   2.118065   21.684642   72.285673
# Bosque laurifolio             15.416053  25.856741   62.928370  100.000000
# Bosque resinoso de coníferas   0.000000   0.005396    2.343792    5.116677
# Bosque siempreverde            0.000000   0.000000    0.001722    0.967843
# Desierto                       0.000189   0.000189    0.000189    0.000189
# Dunas de aerófitos             0.000000   0.000000    0.000000    0.000000
# Estepas y Pastizales           0.000000   0.000000    0.000000    0.000000
# Herbazal de altitud            0.000000   0.000000    0.000000    0.000000
# Herbazal de altitudl           0.000000   0.000000    0.000000    0.000000
# Herbazal efímero               0.152546   0.152546    0.152546    0.152546
# Matorral bajo de altitud       0.000000   0.000000    0.014498    0.378327
# Matorral bajo desértico       -0.002236  -0.002133   -0.000606    0.000000
# Matorral caducifolio           0.000000   0.000000    0.000000    0.000000
# Matorral desértico             0.000000   0.000000    0.025577    0.171827
# Matorral esclerofilo           1.759529   3.516928    5.274327    7.031726
# Matorral espinoso              0.062887   0.098076    0.133264    0.168453
# Matorral siempreverde          0.000000   0.000000    0.000000    0.000000
# Turbera                        0.000000   0.000000    0.000000    0.000000

# %%
print(df_bosque.groupby("Formación")["Pérdida_proyectada_50_años_(%)"].describe())
# Out:
#                               count       mean        std       min  \
# Formación
# Bosque caducifolio             21.0  42.783671  46.788293  0.000000
# Bosque esclerofilo              8.0  43.457923  46.178295  0.000000
# Bosque espinoso                 7.0  16.873649  27.447318 -0.000834
# Bosque laurifolio               3.0  43.610702  49.938188  4.975366
# Bosque resinoso de coníferas    7.0   1.401380   2.336441  0.000000
# Bosque siempreverde            11.0   0.092779   0.290598  0.000000
# Desierto                        1.0   0.000189        NaN  0.000189
# Dunas de aerófitos              1.0   0.000000        NaN  0.000000
# Estepas y Pastizales            4.0   0.000000   0.000000  0.000000
# Herbazal de altitud             4.0   0.000000   0.000000  0.000000
# Herbazal de altitudl            1.0   0.000000        NaN  0.000000
# Herbazal efímero                1.0   0.152546        NaN  0.152546
# Matorral bajo de altitud       20.0   0.026815   0.084822 -0.008080
# Matorral bajo desértico         5.0  -0.002445   0.002854 -0.007248
# Matorral caducifolio            4.0   0.000000   0.000000  0.000000
# Matorral desértico             18.0   0.025853   0.049059 -0.011059
# Matorral esclerofilo            2.0   3.516928   4.970675  0.002130
# Matorral espinoso               2.0   0.098076   0.099528  0.027699
# Matorral siempreverde           1.0   0.000000        NaN  0.000000
# Turbera                         4.0   0.000000   0.000000  0.000000
#
#                                     25%        50%         75%         max
# Formación
# Bosque caducifolio             0.312712   2.433394  100.000000  100.000000
# Bosque esclerofilo             3.688422  25.834129   92.842492  100.000000
# Bosque espinoso                0.171677   2.118065   21.684642   72.285673
# Bosque laurifolio             15.416053  25.856741   62.928370  100.000000
# Bosque resinoso de coníferas   0.000000   0.005396    2.343792    5.116677
# Bosque siempreverde            0.000000   0.000000    0.001722    0.967843
# Desierto                       0.000189   0.000189    0.000189    0.000189
# Dunas de aerófitos             0.000000   0.000000    0.000000    0.000000
# Estepas y Pastizales           0.000000   0.000000    0.000000    0.000000
# Herbazal de altitud            0.000000   0.000000    0.000000    0.000000
# Herbazal de altitudl           0.000000   0.000000    0.000000    0.000000
# Herbazal efímero               0.152546   0.152546    0.152546    0.152546
# Matorral bajo de altitud       0.000000   0.000000    0.014498    0.378327
# Matorral bajo desértico       -0.002236  -0.002133   -0.000606    0.000000
# Matorral caducifolio           0.000000   0.000000    0.000000    0.000000
# Matorral desértico             0.000000   0.000000    0.025577    0.171827
# Matorral esclerofilo           1.759529   3.516928    5.274327    7.031726
# Matorral espinoso              0.062887   0.098076    0.133264    0.168453
# Matorral siempreverde          0.000000   0.000000    0.000000    0.000000
# Turbera                        0.000000   0.000000    0.000000    0.000000

# %%
df_bosque.groupby(["Formación"]).agg(mean_perdidaHistorica=("Pérdida_Histórica_(%)", "mean"),
                                 total=("Superficie_total_(km2)", "count"))
# Out:
#                               mean_perdidaHistorica  total
# Formación
# Bosque caducifolio                        33.936163     21
# Bosque esclerofilo                        43.163663      8
# Bosque espinoso                           41.310998      7
# Bosque laurifolio                         39.049620      3
# Bosque resinoso de coníferas               2.232780      7
# Bosque siempreverde                        3.349238     11
# Desierto                                   2.212528      1
# Dunas de aerófitos                         0.005251      1
# Estepas y Pastizales                       1.245571      4
# Herbazal de altitud                        0.124700      4
# Herbazal de altitudl                       0.343307      1
# Herbazal efímero                           3.328353      1
# Matorral bajo de altitud                   0.370587     20
# Matorral bajo desértico                    0.939844      5
# Matorral caducifolio                       1.991915      4
# Matorral desértico                         4.211099     18
# Matorral esclerofilo                      14.656986      2
# Matorral espinoso                         14.158685      2
# Matorral siempreverde                      0.000000      1
# Turbera                                    0.000000      4
